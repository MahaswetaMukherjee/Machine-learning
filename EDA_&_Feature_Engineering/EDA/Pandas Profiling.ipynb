# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('/Users/mahaswetasarkar/Downloads/titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# !!pip install ydata-profiling
# Out:
# ['Requirement already satisfied: ydata-profiling in /Users/mahaswetasarkar/anaconda3/envs/ml/lib/python3.11/site-packages (4.18.4)',
#  'Requirement already satisfied: scipy<1.17,>=1.8 in /Users/mahaswetasarkar/anaconda3/envs/ml/lib/python3.11/site-packages (from ydata-profiling) (1.16.3)',
#  'Requirement already satisfied: pandas!=1.4.0,<3.0,>1.5 in /Users/mahaswetasarkar/anaconda3/envs/ml/lib/python3.11/site-packages (from ydata-profiling) (2.3.3)',
#  'Requirement already satisfied: matplotlib<=3.10,>=3.5 in /Users/mahaswetasarkar/anaconda3/envs/ml/lib/python3.11/site-packages (from ydata-profiling) (3.10.0)',
#  'Requirement already satisfied: pydantic<3,>=2 in /Users/mahaswetasarkar/anaconda3/envs/ml/lib/python3.11/site-packages (from ydata-profiling) (2.13.4)',
#  'Requirement already satisfied: PyYAML<6.1,>=6.0.3 in /Users/mahaswetasarkar/anaconda3/envs/ml/lib/python3.11/site-packages (from ydata-profiling) (6.0.3)',
#  'Requirement already satisfied: jinja2<3.2,>=3.1.6 in /Users/mahaswetasarkar/anaconda3/envs/ml/lib/python3.11/site-packages (from ydata-profiling) (3.1.6)',
#  'Requirement already satisfied: visions<0.8.2,>=0.7.5 in /Users/mahaswetasarkar/anaconda3/envs/ml/lib/python3.11/site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (0.8.1)',
#  'Requirement already satisfied: numpy<2.4,>=1.22 in /Users/mahaswetasarkar/anaconda3/envs/ml/lib/python3.11/site-packages (from ydata-profiling) (2.3.5)',
#  'Requirement already satisfied: minify-html>=0.15.0 in /Users/mahaswetasarkar/anaconda3/envs/ml/lib/python3.11/site-packages (from ydata-profiling) (0.18.1)',
#  'Requirement already satisfied: filetype>=1.0.0 in /Users/mahaswetasarkar/anaconda3/envs/ml/lib/python3.11/site-packages (from ydata-profiling) (1.2.0)',
#  'Requirement already satisfied: phik<0.13,>=0.12.5 in /Users/mahaswetasarkar/anaconda3/envs/ml/lib/python3.11/site-packages (from ydata-profiling) (0.12.5)',
#  'Requirement already satisfied: requests<3,>=2.32.0 in /Users/mahaswetasarkar/anaconda3/envs/ml/lib/python3.11/site-packages (from ydata-profiling) (2.34.2)',
#  'Requirement already satisfied: tqdm<5,>=4.66.3 in /Users/mahaswetasarkar/anaconda3/envs/ml/lib/python3.11/site-packages (from ydata-profiling) (4.70.0)',
#  'Requirement already satisfied: seaborn<0.14,>=0.10.1 in /Users/mahaswetasarkar/anaconda3/envs/ml/lib/python3.11/site-packages (from ydata-profiling) (0.13.2)',
#  'Requirement already satisfied: multimethod<2,>=1.4 in /Users/mahaswetasarkar/anaconda3/envs/ml/lib/python3.11/site-packages (from ydata-profiling) (1.12)',
#  'Requirement already satisfied: statsmodels<1,>=0.13.2 in /Users/mahaswetasarkar/anaconda3/envs/ml/lib/python3.11/site-packages (from ydata-profiling) (0.14.6)',
#  'Requirement already satisfied: typeguard<5,>=4 in /Users/mahaswetasarkar/anaconda3/envs/ml/lib/python3.11/site-packages (from ydata-profiling) (4.6.0)',
#  'Requirement already satisfied: imagehash==4.3.2 in /Users/mahaswetasarkar/anaconda3/envs/ml/lib/python3.11/site-packages (from ydata-profiling) (4.3.2)',
#  'Requirement already satisfied: wordcloud>=1.9.4 in /Users/mahaswetasarkar/anaconda3/envs/ml/lib/python3.11/site-packages (from ydata-profiling) (1.9.6)',
#  'Requirement already satisfied: dacite<2,>=1.9 in /Users/mahaswetasarkar/anaconda3/envs/ml/lib/python3.11/site-packages (from ydata-profiling) (1.9.2)',
#  'Requirement already satisfied: numba<0.63,>=0.60 in /Users/mahaswetasarkar/anaconda3/envs/ml/lib/python3.11/site-packages (from ydata-profiling) (0.62.1)',
#  'Requirement already satisfied: PyWavelets in /Users/mahaswetasarkar/anaconda3/envs/ml/lib/python3.11/site-packages (from imagehash==4.3.2->ydata-profiling) (1.9.0)',
#  'Requirement already satisfied: pillow in /Users/mahaswetasarkar/anaconda3/envs/ml/lib/python3.11/site-packages (from imagehash==4.3.2->ydata-profiling) (12.3.0)',
#  'Requirement already satisfied: MarkupSafe>=2.0 in /Users/mahaswetasarkar/anaconda3/envs/ml/lib/python3.11/site-packages (from jinja2<3.2,>=3.1.6->ydata-profiling) (3.0.3)',
#  'Requirement already satisfied: contourpy>=1.0.1 in /Users/mahaswetasarkar/anaconda3/envs/ml/lib/python3.11/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.3.3)',
#  'Requirement already satisfied: cycler>=0.10 in /Users/mahaswetasarkar/anaconda3/envs/ml/lib/python3.11/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (0.12.1)',
#  'Requirement already satisfied: fonttools>=4.22.0 in /Users/mahaswetasarkar/anaconda3/envs/ml/lib/python3.11/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (4.63.0)',
#  'Requirement already satisfied: kiwisolver>=1.3.1 in /Users/mahaswetasarkar/anaconda3/envs/ml/lib/python3.11/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.5.0)',
#  'Requirement already satisfied: packaging>=20.0 in /Users/mahaswetasarkar/anaconda3/envs/ml/lib/python3.11/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (26.2)',
#  'Requirement already satisfied: pyparsing>=2.3.1 in /Users/mahaswetasarkar/anaconda3/envs/ml/lib/python3.11/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (3.3.2)',
#  'Requirement already satisfied: python-dateutil>=2.7 in /Users/mahaswetasarkar/anaconda3/envs/ml/lib/python3.11/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (2.9.0.post0)',
#  'Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in /Users/mahaswetasarkar/anaconda3/envs/ml/lib/python3.11/site-packages (from numba<0.63,>=0.60->ydata-profiling) (0.45.1)',
#  'Requirement already satisfied: pytz>=2020.1 in /Users/mahaswetasarkar/anaconda3/envs/ml/lib/python3.11/site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2026.3.post1)',
#  'Requirement already satisfied: tzdata>=2022.7 in /Users/mahaswetasarkar/anaconda3/envs/ml/lib/python3.11/site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2026.3)',
#  'Requirement already satisfied: joblib>=0.14.1 in /Users/mahaswetasarkar/anaconda3/envs/ml/lib/python3.11/site-packages (from phik<0.13,>=0.12.5->ydata-profiling) (1.5.3)',
#  'Requirement already satisfied: annotated-types>=0.6.0 in /Users/mahaswetasarkar/anaconda3/envs/ml/lib/python3.11/site-packages (from pydantic<3,>=2->ydata-profiling) (0.8.0)',
#  'Requirement already satisfied: pydantic-core==2.46.4 in /Users/mahaswetasarkar/anaconda3/envs/ml/lib/python3.11/site-packages (from pydantic<3,>=2->ydata-profiling) (2.46.4)',
#  'Requirement already satisfied: typing-extensions>=4.14.1 in /Users/mahaswetasarkar/anaconda3/envs/ml/lib/python3.11/site-packages (from pydantic<3,>=2->ydata-profiling) (4.16.0)',
#  'Requirement already satisfied: typing-inspection>=0.4.2 in /Users/mahaswetasarkar/anaconda3/envs/ml/lib/python3.11/site-packages (from pydantic<3,>=2->ydata-profiling) (0.4.4)',
#  'Requirement already satisfied: charset_normalizer<4,>=2 in /Users/mahaswetasarkar/anaconda3/envs/ml/lib/python3.11/site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.5.1)',
#  'Requirement already satisfied: idna<4,>=2.5 in /Users/mahaswetasarkar/anaconda3/envs/ml/lib/python3.11/site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.18)',
#  'Requirement already satisfied: urllib3<3,>=1.26 in /Users/mahaswetasarkar/anaconda3/envs/ml/lib/python3.11/site-packages (from requests<3,>=2.32.0->ydata-profiling) (2.7.0)',
#  'Requirement already satisfied: certifi>=2023.5.7 in /Users/mahaswetasarkar/anaconda3/envs/ml/lib/python3.11/site-packages (from requests<3,>=2.32.0->ydata-profiling) (2026.7.22)',
#  'Requirement already satisfied: patsy>=0.5.6 in /Users/mahaswetasarkar/anaconda3/envs/ml/lib/python3.11/site-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (1.0.2)',
#  'Requirement already satisfied: attrs>=19.3.0 in /Users/mahaswetasarkar/anaconda3/envs/ml/lib/python3.11/site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (26.1.0)',
#  'Requirement already satisfied: networkx>=2.4 in /Users/mahaswetasarkar/anaconda3/envs/ml/lib/python3.11/site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (3.6.1)',
#  'Requirement already satisfied: puremagic in /Users/mahaswetasarkar/anaconda3/envs/ml/lib/python3.11/site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (1.30)',
#  'Requirement already satisfied: six>=1.5 in /Users/mahaswetasarkar/anaconda3/envs/ml/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata-profiling) (1.17.0)']

# %%
from ydata_profiling import ProfileReport
prof = ProfileReport(df)
prof.to_file(output_file = 'output.html')
# Out:
# /var/folders/m3/9738wvxj3vgg098r9zz0wzkr0000gn/T/ipykernel_5820/3662742699.py:1: DeprecationWarning:
#     `import ydata_profiling` is deprecated and will not receive more updates.
#     Please install fg-data-profiling via `pip install fg-data-profiling` and use `import data_profiling` instead.
#
#   from ydata_profiling import ProfileReport
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████| 12/12 [00:00<00:00, 4264.31it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# !pip install setuptools
# Out:
# Requirement already satisfied: setuptools in /Users/mahaswetasarkar/anaconda3/envs/ml/lib/python3.11/site-packages (83.0.0)

# %%
import sys
print(sys.executable)
# Out:
# /Users/mahaswetasarkar/anaconda3/envs/ml/bin/python3.11

# %%
# !pip install "setuptools<82"
# Out:
# Collecting setuptools<82
#   Downloading setuptools-81.0.0-py3-none-any.whl.metadata (6.6 kB)
# Downloading setuptools-81.0.0-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 5.8 MB/s  0:00:00m 7.0 MB/s eta 0:00:01
# Installing collected packages: setuptools
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 83.0.0
#     Uninstalling setuptools-83.0.0:
#       Successfully uninstalled setuptools-83.0.0
# Successfully installed setuptools-81.0.0
